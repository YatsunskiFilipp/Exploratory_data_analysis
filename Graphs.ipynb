# %% [markdown]
# # LINE GRAPHS IN MATPLOTLIB

# %% [markdown]
# ### Dashed:
# plt.plot(x_values, y_values, linestyle='--')
# ### Dotted:
# plt.plot(x_values, y_values, linestyle=':')
# ### No line:
# plt.plot(x_values, y_values, linestyle='')
#
# ### A circle:
# plt.plot(x_values, y_values, marker='o')
# ### A square:
# plt.plot(x_values, y_values, marker='s')
# ### A star:
# plt.plot(x_values, y_values, marker='*')

# %% [markdown]
# We can customize the spacing between our subplots to make sure that the figure we create is visible and easy to understand. To do this, we use the plt.subplots_adjust() command. .subplots_adjust() has some keyword arguments that can move your plots within the figure:
#
# left — the left-side margin, with a default of 0.125. You can increase this number to make room for a y-axis label
#
# right — the right-side margin, with a default of 0.9. You can increase this to make more room for the figure, or decrease it to make room for a legend
#
# bottom — the bottom margin, with a default of 0.1. You can increase this to make room for tick mark labels or an x-axis label
#
# top — the top margin, with a default of 0.9
#
# wspace — the horizontal space between adjacent subplots, with a default of 0.2
#
# hspace — the vertical space between adjacent subplots, with a default of 0.2

# %% [markdown]
# ## Legends
# When we have multiple lines on a single graph we can label them by using the command plt.legend().
#
# Number Code	String
# 0	best
#
# 1	upper right
#
# 2	upper left
#
# 3	lower left
#
# 4	lower right
#
# 5	right
#
# 6	center left
#
# 7	center right
#
# 8	lower center
#
# 9	upper center
#
# 10	center

# %%
#import codecademylib
from matplotlib import pyplot as plt

time = [0, 1, 2, 3, 4]
revenue = [200, 400, 650, 800, 850]
costs = [150, 500, 550, 550, 560]

# %%
plt.plot(time, revenue, color = 'purple', linestyle = '--')
plt.plot(time, costs, color = '#82edc9', marker = 's')
plt.legend(['revenue','costs'])
plt.show()

# %%
x = range(12)
y = [3000, 3005, 3010, 2900, 2950, 3050, 3000, 3100, 2980, 2980, 2920, 3010]
plt.plot(x, y)

#your code here

plt.show()

# %%
plt.plot(x,y, color = 'red', linestyle = "--", marker = "o")
plt.axis([0, 12, 2900, 3100])
plt.xlabel('Time')
plt.ylabel('Dollars spent on coffee')
plt.title('My Last Twelve Years of Coffee Drinking')
plt.show()

# %%
months = range(12)
temperature = [36, 36, 39, 52, 61, 72, 77, 75, 68, 57, 48, 48]
flights_to_hawaii = [1200, 1300, 1100, 1450, 850, 750, 400, 450, 400, 860, 990, 1000]

plt.subplot(1,2,1)
plt.plot(months,temperature,color = 'steelblue', linestyle = '--', marker = 's')
plt.title('1')
plt.xlabel('months')
plt.ylabel('temperature')

plt.subplot(1,2,2)
plt.plot(temperature,flights_to_hawaii, 'o')
plt.title('2')
plt.xlabel('temperature')
plt.ylabel('flights_to_hawaii')

plt.subplots_adjust(right = 2)
plt.show()

# %%
x = range(7)
straight_line = [0, 1, 2, 3, 4, 5, 6]
parabola = [0, 1, 4, 9, 16, 25, 36]
cubic = [0, 1, 8, 27, 64, 125, 216]

plt.subplot(2,1,1)
plt.plot(x, straight_line, color = 'red', linestyle = '--', marker = 's')
plt.ylabel('straight_line')
plt.title('straight_line vs x')

plt.subplot(2,2,3)
plt.plot(x, parabola, color = 'steelblue')
plt.ylabel('parabola')
plt.title('parabola vs x')

plt.subplot(2,2,4)
plt.plot(x, cubic, color = 'pink')
plt.ylabel('cubic')
plt.title('cubic vs x')

plt.subplots_adjust(bottom = 0.2, wspace = 0.35, hspace = 0.5)
plt.show()

# %%
months = range(12)
hyrule = [63, 65, 68, 70, 72, 72, 73, 74, 71, 70, 68, 64]
kakariko = [52, 52, 53, 68, 73, 74, 74, 76, 71, 62, 58, 54]
gerudo = [98, 99, 99, 100, 99, 100, 98, 101, 101, 97, 98, 99]
legend_labels = ['Hyrule','Kakariko','Gerudo Valley']

plt.plot(months, hyrule, color = 'grey')
plt.plot(months, kakariko, linestyle = '--')
plt.plot(months, gerudo)
plt.title('Games')

plt.legend(legend_labels, loc = 8)

plt.show()

# %%
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep","Oct", "Nov", "Dec"]

months = range(12)
conversion = [0.05, 0.08, 0.18, 0.28, 0.4, 0.66, 0.74, 0.78, 0.8, 0.81, 0.85, 0.85]

plt.xlabel("Months")
plt.ylabel("Conversion")

plt.plot(months, conversion)

ax = plt.subplot()
ax.set_xticks(months)
ax.set_xticklabels(month_names)
ax.set_yticks([0.10, 0.25, 0.5, 0.75])
ax.set_yticklabels(['10%', '25%','50%','75%',])


plt.show()
# Out:
# C:\ANAC2\lib\site-packages\ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # This is added back by InteractiveShellApp.init_path()

# %%
word_length = [8, 11, 12, 11, 13, 12, 9, 9, 7, 9]
power_generated = [753.9, 768.8, 780.1, 763.7, 788.5, 782, 787.2, 806.4, 806.2, 798.9]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

plt.figure(figsize=(10,5))
plt.title('Power words')

plt.xlabel('Year')
ax = plt.subplot(2,1,1)
plt.plot(years, word_length)
plt.ylabel('word_length')


ax = plt.subplot(2,1,2)
plt.plot(years, power_generated, color = 'red')
plt.ylabel('power_generated')


plt.subplots_adjust(bottom = 0.2, wspace = 0.35, hspace = 0.5)
plt.show()

# %%
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep","Oct", "Nov", "Dec"]
x = range(12)
y1 = [5000*i for i in x]
y2 = [i**5 for i in x]
legend = ['2010', '2020']

plt.plot(x,y1, color = 'steelblue', linestyle = '--')
plt.plot(x,y2, color = 'pink', marker = 'o')
#ax = plt.subplot()

plt.title('Dynamics')
plt.xlabel('Month')
plt.ylabel('Quantity')
plt.legend(legend)

ax = plt.subplot()
ax.set_xticks(x)
ax.set_xticklabels(month_names)

plt.show()
# Out:
# C:\ANAC2\lib\site-packages\ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   app.launch_new_instance()

# %% [markdown]
# # Sublime Limes' Line Graphs (Project)

# %%
#import codecademylib
#from matplotlib import pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

visits_per_month = [9695, 7909, 10831, 12942, 12495, 16794, 14161, 12762, 12777, 12439, 10309, 8724]

# numbers of limes of different species sold each month
key_limes_per_month = [92.0, 109.0, 124.0, 70.0, 101.0, 79.0, 106.0, 101.0, 103.0, 90.0, 102.0, 106.0]
persian_limes_per_month = [67.0, 51.0, 57.0, 54.0, 83.0, 90.0, 52.0, 63.0, 51.0, 44.0, 64.0, 78.0]
blood_limes_per_month = [75.0, 75.0, 76.0, 71.0, 74.0, 77.0, 69.0, 80.0, 63.0, 69.0, 73.0, 82.0]

x_values = range(len(months))

plt.figure(figsize=(12,8))


ax1 = plt.subplot(1,2,1)
plt.plot(x_values, visits_per_month, color = 'steelblue', marker = '*')
plt.xlabel('Months')
plt.ylabel('visits_per_month')
plt.title('Visits dynamics')
ax.set_xticks(x_values)
ax1.set_xticklabels(months)

ax2 = plt.subplot(1,2,2)
plt.plot(x_values, key_limes_per_month, color = 'pink')
plt.plot(x_values, persian_limes_per_month, color = 'green')
plt.plot(x_values, blood_limes_per_month, color = 'gray')
plt.xlabel('Months')
plt.ylabel('Number of limes')
plt.legend(['Key', 'Persian', 'Blood'])
plt.title('Limes dynamics')
ax2.set_xticks(x_values)
ax2.set_xticklabels(months)

plt.subplots_adjust(right = 1.2, left = 0.3)
#plt.savefig('Limes.png')
plt.show()
# Out:
# C:\ANAC2\lib\site-packages\ipykernel_launcher.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales =  [91, 76, 56, 66, 52, 27]


plt.bar(range(len(drinks)), sales)
ax = plt.subplot()
ax.set_xticks(range(len(drinks)))
ax.set_xticklabels(drinks)
rotation = 30
plt.xlabel('Drinks')
plt.ylabel('Sales')
#create your ax object here

plt.show()
# Out:
# C:\ANAC2\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 = [91, 76, 56, 66, 52, 27]
sales2 = [65, 82, 36, 68, 38, 40]
legends = ['Location 1','Location 2']

#Paste the x_values code here
n = 1  # This is our first dataset (out of 2)
t = 2 # Number of dataset
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar
store1_x = [t*element + w*n for element
             in range(d)]
plt.bar(store1_x, sales1)
ax = plt.subplot()
plt.legend(legend)

#Paste the x_values code here
n = 2  # This is our second dataset (out of 2)
t = 2 # Number of dataset
d = 6 # Number of sets of bars
w = 0.8 # Width of each bar
store2_x = [t*element + w*n for element
             in range(d)]
plt.bar(store2_x, sales2)
plt.legend(legends)

middles = [(i+j)/2 for (i,j) in zip(store1_x,store2_x)]

ax.set_xticks(middles)
ax.set_xticklabels(drinks)

plt.show()
# Out:
# C:\ANAC2\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
print(store1_x)
print(store2_x)
# Out:
# [0.8, 2.8, 4.8, 6.8, 8.8, 10.8]
# [1.6, 3.6, 5.6, 7.6, 9.6, 11.6]

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]
sales1 =  [91, 76, 56, 66, 52, 27]
sales2 = [65, 82, 36, 68, 38, 40]
legend = ['Location 1','Location 2']

#plt.bar(range(len(drinks)), sales1)
#plt.bar(range(len(drinks)), sales2, bottom=sales1)

plt.bar(range(len(drinks)), sales1)

ax = plt.subplot()
ax.set_xticks(range(len(drinks)))
ax.set_xticklabels(drinks)
plt.bar(range(len(drinks)), sales2, bottom=sales1)
plt.legend(legend)

plt.show()
# Out:
# C:\ANAC2\lib\site-packages\ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # This is added back by InteractiveShellApp.init_path()

# %%
drinks = ["cappuccino", "latte", "chai", "americano", "mocha", "espresso"]

drinkss = [ i + '' for i in drinks]
len(drinks)
# Out:
# 6

# %%
months = range(12)
month_names = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
revenue = [16000, 14000, 17500, 19500, 21500, 21500, 22000, 23000, 20000, 19500, 18000, 16500]
y_lower = [i - i*0.1 for i in revenue]
y_upper = [i + i*0.1 for i in revenue]

ax = plt.subplot()
plt.plot(range(len(month_names)), revenue) 
ax.set_xticks(range(len(month_names)))
ax.set_xticklabels(month_names)
plt.fill_between(range(len(month_names)), y_lower, y_upper, alpha = 0.2)
plt.show()

# %%
payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

plt.pie(payment_method_freqs, labels = payment_method_names, autopct = '%0.1f%%')
plt.axis('equal')
plt.show()

# %%
payment_method_names = ["Card Swipe", "Cash", "Apple Pay", "Other"]
payment_method_freqs = [270, 77, 32, 11]

plt.pie(payment_method_freqs, autopct = '%0.1f%%')
plt.legend(payment_method_names)

plt.show()

# %%
from random import randint
numbers1 = []
numbers2 = []
for i in range(500):
    numbers1.append(randint(0,50))
    numbers2.append(randint(30,130))


plt.hist(numbers1, bins = 25, alpha = 0.4, normed = True)
plt.hist(numbers2, bins = 25, alpha = 0.4, normed = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-be5363cde51a> in <module>
#       7
#       8
# ----> 9 plt.hist(numbers1, bins = 25, alpha = 0.4, normed = True)
#      10 plt.hist(numbers2, bins = 25, alpha = 0.4, normed = True)
#      11 plt.show()
#
# C:\ANAC2\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2688         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2689         color=color, label=label, stacked=stacked,
# -> 2690         **({"data": data} if data is not None else {}), **kwargs)
#    2691
#    2692
#
# C:\ANAC2\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# ...

# %%
nn = ['numbers1', 'numbers2']
plt.hist(numbers1, bins = 25, histtype='step')
plt.hist(numbers2, bins = 25, histtype='step')
plt.legend(nn)
plt.show()

# %%
past_years_averages = [82, 84, 83, 86, 74, 84, 90]
years = [2000, 2001, 2002, 2003, 2004, 2005, 2006]
error = [1.5, 2.1, 1.2, 3.2, 2.3, 1.7, 2.4]

plt.figure(figsize = (10, 8))
ax = plt.subplot()
plt.bar(range(len(years)), past_years_averages, yerr = error, capsize = 5)
plt.axis([-0.5, 6.5, 70, 95])

ax.set_xticks(range(len(years)))
ax.set_xticklabels(years)

plt.title('Final Exam Averages')
plt.xlabel('Year')
plt.ylabel('Test average')

plt.savefig('my_bar_chart.png')

plt.show()

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
middle_school_a = [80, 85, 84, 83, 86]
middle_school_b = [73, 78, 77, 82, 86]
legends = ['Middle School A', 'Middle School B']


def create_x(t, w, n, d):
    return [t*x + w*n for x in range(d)]
school_a_x = create_x(2, 0.8, 1, len(unit_topics))
school_b_x  = create_x(2, 0.8, 2, len(unit_topics))
middle_x = [(i+j)/2.0 for i,j in zip(school_a_x, school_b_x)]

plt.figure(figsize = (10, 8))
ax = plt.subplot()
plt.bar(school_a_x, middle_school_a, color = 'red')
plt.bar(school_b_x, middle_school_b, color = 'steelblue')
ax.set_xticks(middle_x)
ax.set_xticklabels(unit_topics)
plt.legend(legends)
plt.title('Test Averages on Different Units')
plt.xlabel('Unit')
plt.ylabel('Test Average')
#plt.savefig('my_side_by_side.png')

plt.show()

# %%
print(school_a_x)
print(school_b_x)
# Out:
# [0.8, 2.8, 4.8, 6.8, 8.8]
# [1.6, 3.6, 5.6, 7.6, 9.6]

# %%
import numpy as np

unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
As = [6, 3, 4, 3, 5]
Bs = [8, 12, 8, 9, 10]
Cs = [13, 12, 15, 13, 14]
Ds = [2, 3, 3, 2, 1]
Fs = [1, 0, 0, 3, 0]

x = range(5)

c_bottom = np.add(As, Bs)
d_bottom = np.add(c_bottom, Cs)
f_bottom = np.add(d_bottom, Ds)
#create your plot here
plt.figure(figsize = (10,8))
plt.bar(x, As)
plt.bar(x, Bs, bottom = As)
plt.bar(x, Cs, bottom = c_bottom)
plt.bar(x, Ds, bottom = d_bottom)
plt.bar(x, Fs, bottom = f_bottom)

ax = plt.subplot()
ax.set_xticks(range(len(unit_topics)))
ax.set_xticklabels(unit_topics)

plt.title('Grade distribution')
plt.ylabel('Number of students')
plt.xlabel('Unit')

#plt.savefig('my_stacked_bar.png')

plt.show()
# Out:
# C:\ANAC2\lib\site-packages\ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
d_bottom
# Out:
# array([27, 27, 27, 25, 29])

# %%
exam_scores1 = [62.58, 67.63, 81.37, 52.53, 62.98, 72.15, 59.05, 73.85, 97.24, 76.81, 89.34, 74.44, 68.52, 85.13, 90.75, 70.29, 75.62, 85.38, 77.82, 98.31, 79.08, 61.72, 71.33, 80.77, 80.31, 78.16, 61.15, 64.99, 72.67, 78.94]
exam_scores2 = [72.38, 71.28, 79.24, 83.86, 84.42, 79.38, 75.51, 76.63, 81.48,78.81,79.23,74.38,79.27,81.07,75.42,90.35,82.93,86.74,81.33,95.1,86.57,83.66,85.58,81.87,92.14,72.15,91.64,74.21,89.04,76.54,81.9,96.5,80.05,74.77,72.26,73.23,92.6,66.22,70.09,77.2]
legends = ["1st Yr Teaching", "2nd Yr Teaching"]

plt.figure(figsize = (10,8))

plt.hist(exam_scores1, bins = 12, normed = True, histtype = 'step', linewidth = 2)
plt.hist(exam_scores2, bins = 12, normed = True, histtype = 'step', linewidth = 2)

plt.legend(legends)
plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.title('Final Exam Score Distribution')

#plt.savefig('my_histogram.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-0c4adcb02ac5> in <module>
#       5 plt.figure(figsize = (10,8))
#       6
# ----> 7 plt.hist(exam_scores1, bins = 12, normed = True, histtype = 'step', linewidth = 2)
#       8 plt.hist(exam_scores2, bins = 12, normed = True, histtype = 'step', linewidth = 2)
#       9
#
# C:\ANAC2\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2688         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2689         color=color, label=label, stacked=stacked,
# -> 2690         **({"data": data} if data is not None else {}), **kwargs)
#    2691
#    2692
#
# C:\ANAC2\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
exam_scores1 = [62.58, 67.63, 81.37, 52.53, 62.98, 72.15, 59.05, 73.85, 97.24, 76.81, 89.34, 74.44, 68.52, 85.13, 90.75, 70.29, 75.62, 85.38, 77.82, 98.31, 79.08, 61.72, 71.33, 80.77, 80.31, 78.16, 61.15, 64.99, 72.67, 78.94]
exam_scores2 = [72.38, 71.28, 79.24, 83.86, 84.42, 79.38, 75.51, 76.63, 81.48,78.81,79.23,74.38,79.27,81.07,75.42,90.35,82.93,86.74,81.33,95.1,86.57,83.66,85.58,81.87,92.14,72.15,91.64,74.21,89.04,76.54,81.9,96.5,80.05,74.77,72.26,73.23,92.6,66.22,70.09,77.2]
legends = ["1st Yr Teaching", "2nd Yr Teaching"]

plt.figure(figsize = (10,8))

plt.hist(exam_scores1, bins = 12, normed = True, linewidth = 2, alpha = 0.2, color = 'red')
plt.hist(exam_scores2, bins = 12, normed = True, linewidth = 2, alpha = 0.2, color = 'green')

plt.legend(legends)
plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.title('Final Exam Score Distribution')

#plt.savefig('my_histogram.png')
plt.show()

# %%
unit_topics = ['Limits', 'Derivatives', 'Integrals', 'Diff Eq', 'Applications']
num_hardest_reported = [1, 3, 10, 15, 1]

plt.figure(figsize = (10,8))

plt.pie(num_hardest_reported, labels = unit_topics, autopct = '%d%%')
plt.axis('equal')
plt.title('Hardest Topics')
#plt.savefig('my_pie_chart.png')
plt.show()

# %%
hours_reported =[3, 2.5, 2.75, 2.5, 2.75, 3.0, 3.5, 3.25, 3.25,  3.5, 3.5, 3.75, 3.75,4, 4.0, 3.75,  4.0, 4.25, 4.25, 4.5, 4.5, 5.0, 5.25, 5, 5.25, 5.5, 5.5, 5.75, 5.25, 4.75]
exam_scores = [52.53, 59.05, 61.15, 61.72, 62.58, 62.98, 64.99, 67.63, 68.52, 70.29, 71.33, 72.15, 72.67, 73.85, 74.44, 75.62, 76.81, 77.82, 78.16, 78.94, 79.08, 80.31, 80.77, 81.37, 85.13, 85.38, 89.34, 90.75, 97.24, 98.31]

hours_lower_bound = [i - i*0.2 for i in hours_reported]
hours_upper_bound = [i + i*0.2 for i in hours_reported]

plt.figure(figsize = (10,8))
plt.plot(exam_scores, hours_reported, linewidth = 5)
plt.fill_between(exam_scores, hours_lower_bound, hours_upper_bound, alpha = 0.2)

plt.title('Time spent studying vs final exam scores')
plt.xlabel('Score')
plt.ylabel('Hours studying (self-reported)')

#plt.savefig('my_line_graph.png')

plt.show()

# %% [markdown]
# # Pandas DataFrame

# %% [markdown]
# ### Фильтрация

# %%
import pandas as pd

df2 = pd.DataFrame([
  [1, 'San Diego', 100],
  [2, 'Los Angeles', 120],
  [3,	'San Francisco',	90],
  [4,	'Sacramento',	115]
],
  columns=[
    'Store ID', 'Location',	'Number of Employees'
  ])

print(df2)
# Out:
#    Store ID       Location  Number of Employees
# 0         1      San Diego                  100
# 1         2    Los Angeles                  120
# 2         3  San Francisco                   90
# 3         4     Sacramento                  115

# %%
df = pd.DataFrame([
  ['January', 100, 100, 23, 100],
  ['February', 51, 45, 145, 45],
  ['March', 81, 96, 65, 96],
  ['April', 80, 80, 54, 180],
  ['May', 51, 54, 54, 154],
  ['June', 112, 109, 79, 129]],
  columns=['month', 'clinic_east',
           'clinic_north', 'clinic_south',
           'clinic_west']
)
print(df)
print()
clinic_north = df.clinic_north
print(clinic_north)
print()
print(type(clinic_north))
# Out:
#       month  clinic_east  clinic_north  clinic_south  clinic_west
# 0   January          100           100            23          100
# 1  February           51            45           145           45
# 2     March           81            96            65           96
# 3     April           80            80            54          180
# 4       May           51            54            54          154
# 5      June          112           109            79          129
#
# 0    100
# 1     45
# 2     96
# 3     80
# 4     54
# 5    109
# Name: clinic_north, dtype: int64
#
# <class 'pandas.core.series.Series'>

# %%
clinic_north_south = df[['clinic_north', 'clinic_south']]
print(clinic_north_south)
print()
print(type(clinic_north_south))
# Out:
#    clinic_north  clinic_south
# 0           100            23
# 1            45           145
# 2            96            65
# 3            80            54
# 4            54            54
# 5           109            79
#
# <class 'pandas.core.frame.DataFrame'>

# %%
march = df.iloc[2]
print(march)
print()
print(type(march))
# Out:
# month           March
# clinic_east        81
# clinic_north       96
# clinic_south       65
# clinic_west        96
# Name: 2, dtype: object
#
# <class 'pandas.core.series.Series'>

# %%
april_may_june = df.iloc[3:6]
print(april_may_june)
print()
print(type(april_may_june))
# Out:
#    month  clinic_east  clinic_north  clinic_south  clinic_west
# 3  April           80            80            54          180
# 4    May           51            54            54          154
# 5   June          112           109            79          129
#
# <class 'pandas.core.frame.DataFrame'>

# %%
january = df[df.month == 'January']
print(january)
# Out:
#      month  clinic_east  clinic_north  clinic_south  clinic_west
# 0  January          100           100            23          100

# %%
jan = df[df['month'] == 'January']
print(january)
# Out:
#      month  clinic_east  clinic_north  clinic_south  clinic_west
# 0  January          100           100            23          100

# %%
march_april = df[(df.month == 'March') | (df.month == 'April')]
print(march_april)

print()

mar_apr = df[(df['month'] == 'March') | (df['month'] == 'April')]
print(mar_apr)
# Out:
#    month  clinic_east  clinic_north  clinic_south  clinic_west
# 2  March           81            96            65           96
# 3  April           80            80            54          180
#
#    month  clinic_east  clinic_north  clinic_south  clinic_west
# 2  March           81            96            65           96
# 3  April           80            80            54          180

# %%
january_february_march = df[df.month.isin(['January', 'February', 'March'])]
print(january_february_march)

january_february_marc = df[df['month'].isin(['January', 'February', 'March'])]
print()
print(january_february_marc)
# Out:
#       month  clinic_east  clinic_north  clinic_south  clinic_west
# 0   January          100           100            23          100
# 1  February           51            45           145           45
# 2     March           81            96            65           96
#
#       month  clinic_east  clinic_north  clinic_south  clinic_west
# 0   January          100           100            23          100
# 1  February           51            45           145           45
# 2     March           81            96            65           96

# %%
df[df['month'].isin(['January', 'February', 'March'])]
# Out:
#       month  clinic_east  clinic_north  clinic_south  clinic_west
# 0   January          100           100            23          100
# 1  February           51            45           145           45
# 2     March           81            96            65           96

# %%
df2 = df.loc[[1, 3, 5]]

# print(df2)

df3 = df2.reset_index()

print(df3)

df2.reset_index(inplace = True, drop = True)

print(df2)
# Out:
#    index     month  clinic_east  clinic_north  clinic_south  clinic_west
# 0      1  February           51            45           145           45
# 1      3     April           80            80            54          180
# 2      5      June          112           109            79          129
#       month  clinic_east  clinic_north  clinic_south  clinic_west
# 0  February           51            45           145           45
# 1     April           80            80            54          180
# 2      June          112           109            79          129

# %% [markdown]
# ### Работа со столбцами и заголовками

# %%
df = pd.DataFrame([
  [1, '3 inch screw', 0.5, 0.75],
  [2, '2 inch nail', 0.10, 0.25],
  [3, 'hammer', 3.00, 5.50],
  [4, 'screwdriver', 2.50, 3.00]
],
  columns=['Product ID', 'Description', 'Cost to Manufacture', 'Price']
)

df['Sold in Bulk?'] = ['Yes', 'Yes', 'No', 'No']
df['Is taxed?'] = 'Yes'

df['Revenue'] = df['Price']-df['Cost to Manufacture']

df['Price10'] = df.Price * 0.075
df
# Out:
#    Product ID   Description  Cost to Manufacture  Price Sold in Bulk?  \
# 0           1  3 inch screw                  0.5   0.75           Yes
# 1           2   2 inch nail                  0.1   0.25           Yes
# 2           3        hammer                  3.0   5.50            No
# 3           4   screwdriver                  2.5   3.00            No
#
#   Is taxed?  Revenue  Price10
# 0       Yes     0.25  0.05625
# 1       Yes     0.15  0.01875
# 2       Yes     2.50  0.41250
# 3       Yes     0.50  0.22500

# %%
def lowercase(my_string):
  return my_string.lower()

df = pd.DataFrame([
  ['JOHN SMITH', 'john.smith@gmail.com'],
  ['Jane Doe', 'jdoe@yahoo.com'],
  ['joe schmo', 'joeschmo@hotmail.com']
],
  columns=['Name', 'Email']
)

df['Lowercase Name'] = df['Name'].apply(lowercase)

df['Name'] = df['Name'].str.lower()

df.columns = df.columns.str.lower()

df.columns.tolist()

df.columns

df
# Out:
#          name                 email lowercase name
# 0  john smith  john.smith@gmail.com     john smith
# 1    jane doe        jdoe@yahoo.com       jane doe
# 2   joe schmo  joeschmo@hotmail.com      joe schmo

# %%
old_names = df.columns.tolist()
new_names = ['Names', 'E-mail', 'Low']
update = dict(zip(old_names, new_names))
#old_names

update
# Out:
# {'name': 'Names', 'email': 'E-mail', 'lowercase name': 'Low'}

# %%
df.rename(columns = update, inplace = True)
df
# Out:
#         Names                E-mail         Low
# 0  john smith  john.smith@gmail.com  john smith
# 1    jane doe        jdoe@yahoo.com    jane doe
# 2   joe schmo  joeschmo@hotmail.com   joe schmo

# %%
df.rename(columns = {'Low':'Low_name'}, inplace = True)
df
# Out:
#         Names                E-mail    Low_name
# 0  john smith  john.smith@gmail.com  john smith
# 1    jane doe        jdoe@yahoo.com    jane doe
# 2   joe schmo  joeschmo@hotmail.com   joe schmo

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

df = pd.DataFrame([
 ['Male', 7.2],
 ['Female', 8.1],
 ['Non-binary', 6.8],
],
  columns=['Gender', 'Mean Satisfaction']
)
print(df)

sns.barplot(
  data = df,
  x = 'Gender',
  y = 'Mean Satisfaction'
)
plt.show()
# Out:
#        Gender  Mean Satisfaction
# 0        Male                7.2
# 1      Female                8.1
# 2  Non-binary                6.8

# %%
import numpy as np

gradebook = pd.DataFrame([
 ['Amy', 'Assignment 1', 75],
 ['Amy', 'Assignment 2', 82],
 ['Bob', 'Assignment 1', 99],
 ['Bob', 'Assignment 2', 90],
 ['Chris', 'Assignment 1', 72],
 ['Chris', 'Assignment 2', 66],
],
  columns=['Student', 'assignment_name', 'grade']
)
    

assignment1 =  gradebook[gradebook.assignment_name == 'Assignment 1']
asn1_median = np.median(assignment1.grade)

print(asn1_median)
# Out:
# 75.0

# %%
sns.barplot(
  data = gradebook,
  x = 'assignment_name',
  y = 'grade'
)
plt.show()

# %%
sns.barplot(
    data = gradebook,
    x = 'Student',
    y = 'grade',
    ci = 'sd',
    hue = 'assignment_name'
#    estimator = len, np.median
)
plt.show()

# %%
set_one = np.genfromtxt("dataset1.csv", delimiter=",")
set_two = np.genfromtxt("dataset2.csv", delimiter=",")
set_three = np.genfromtxt("dataset3.csv", delimiter=",")
set_four = np.genfromtxt("dataset4.csv", delimiter=",")

# Creating a Pandas DataFrame:
n=500
df = pd.DataFrame({
    "label": ["set_one"] * n + ["set_two"] * n + ["set_three"] * n + ["set_four"] * n,
    "value": np.concatenate([set_one, set_two, set_three, set_four])
})

# Setting styles:
sns.set_style("darkgrid")
sns.set_palette("pastel")

# Add your code below:
sns.barplot(
  data = df,
  x = 'label',
  y = 'value',
)
plt.show()

# %%
df.head()
# Out:
#      label      value
# 0  set_one        NaN
# 1  set_one  54.772845
# 2  set_one  73.637338
# 3  set_one  55.015799
# 4  set_one  83.609378

# %%
sns.kdeplot(set_one, shade = True)
sns.kdeplot(set_two, shade = True)
sns.kdeplot(set_three, shade = True)
sns.kdeplot(set_four, shade = True)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.set_style("darkgrid")
sns.set_palette("pastel")

# Add your code below:
sns.boxplot(
  data = df,
  x = 'label',
  y = 'value',
)
plt.show()

# %%
sns.violinplot(
  data = df,
  x = 'label',
  y = 'value',
)
plt.show()

# %%
sns.violinplot(
  data = df,
  y = 'value',
)
plt.show()

# %% [markdown]
# ## Seaborn project

# %%
# Assign spreadsheet filename to `file`
file = 'WorldCupMatches.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(file)

# Print the sheet names
print(xl.sheet_names)

# Load a sheet into a DataFrame by name: df1
df = xl.parse('WorldCupMatches')
df.head()
# Out:
# ['WorldCupMatches']
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# ...

# %%
#df = pd.read_csv('WorldCupMatches.csv')
#df.head()

# %%
df['Total Goals'] = df['Home Team Goals']+df['Away Team Goals']

sns.set_style('whitegrid')
sns.set_context('poster', font_scale=0.6)

f, ax = plt.subplots(figsize = (12,7))
ax = sns.barplot(
  data = df,
  x = 'Year',
  y = 'Total Goals',
#  estimator = np.sum,median
#  ci = None
)
ax.set_title('Goals per year')
#plt.title('Goals per year')
plt.show()

# %%
df_goals = pd.read_csv('goals.csv')
df_goals.head()
# Out:
#    goals home/away  year
# 0      4      home  1930
# 1      3      home  1930
# 2      2      home  1930
# 3      3      home  1930
# 4      1      home  1930

# %%
sns.set_style('whitegrid')
sns.set_context('notebook', font_scale=1.25)
f, ax2 = plt.subplots(figsize = (12,7))
ax2 = sns.boxplot(
data = df_goals,
x = 'year',
y = 'goals')
#plt.title('Goals distribution')
ax2.set_title('Goals distribution')

plt.show()

# %% [markdown]
# ## Seaborn project  2 Kivi
